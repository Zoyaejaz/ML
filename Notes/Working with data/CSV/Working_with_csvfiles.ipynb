# %% [markdown]
# # 1.Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# # 2. Opening a Local CSV file

# %%
pd.read_csv("insurance.csv")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # 3. Opening a csv file from an URL

# %%
import requests
from io import StringIO
url=""
headers={"give the link of the dataset"}
req=requests.get(url,headers=headers)
data=StringIO(req.test)

pd.read_csv(data)
# Out:
# ---------------------------------------------------------------------------
# MissingSchema                             Traceback (most recent call last)
# Cell In[4], line 5
#       3 url=""
#       4 headers={"give the link of the dataset"}
# ----> 5 req=requests.get(url,headers=headers)
#       6 data=StringIO(req.test)
#       8 pd.read_csv(data)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
# ...

# %% [markdown]
# # 4. Sep  Parameter

# %%
pd.read_csv('movie_titles_metadata.tsv',sep='\t',names=['sno','name','release_year','rating','votes','genres'])
# Out:
#       sno                        name release_year  rating     votes  \
# 0      m0  10 things i hate about you         1999     6.9   62847.0
# 1      m1  1492: conquest of paradise         1992     6.2   10421.0
# 2      m2                  15 minutes         2001     6.1   25854.0
# 3      m3       2001: a space odyssey         1968     8.4  163227.0
# 4      m4                     48 hrs.         1982     6.9   22289.0
# ..    ...                         ...          ...     ...       ...
# 612  m612                    watchmen         2009     7.8  135229.0
# 613  m613                         xxx         2002     5.6   53505.0
# 614  m614                       x-men         2000     7.4  122149.0
# 615  m615          young frankenstein         1974     8.0   57618.0
# 616  m616                   zulu dawn         1979     6.4    1911.0
#
#                                                 genres
# 0                                 ['comedy' 'romance']
# ...

# %% [markdown]
# # 5. Index_col parameter

# %%
pd.read_csv('insurance.csv')
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # 6. Header parameter

# %%
pd.read_csv('insurance.csv',header=1) #header=1, helps to start the row from 1
# Out:
#       19  female    27.9  0  yes  southwest    16884.924
# 0     18    male  33.770  1   no  southeast   1725.55230
# 1     28    male  33.000  3   no  southeast   4449.46200
# 2     33    male  22.705  0   no  northwest  21984.47061
# 3     32    male  28.880  0   no  northwest   3866.85520
# 4     31  female  25.740  0   no  southeast   3756.62160
# ...   ..     ...     ... ..  ...        ...          ...
# 1332  50    male  30.970  3   no  northwest  10600.54830
# 1333  18  female  31.920  0   no  northeast   2205.98080
# 1334  18  female  36.850  0   no  southeast   1629.83350
# 1335  21  female  25.800  0   no  southwest   2007.94500
# 1336  61  female  29.070  0  yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %% [markdown]
# # 7.use_cols parame

# %%
pd.read_csv('insurance.csv',usecols=['age','children','bmi','smoker','charges'])
# Out:
#       age     bmi  children smoker      charges
# 0      19  27.900         0    yes  16884.92400
# 1      18  33.770         1     no   1725.55230
# 2      28  33.000         3     no   4449.46200
# 3      33  22.705         0     no  21984.47061
# 4      32  28.880         0     no   3866.85520
# ...   ...     ...       ...    ...          ...
# 1333   50  30.970         3     no  10600.54830
# 1334   18  31.920         0     no   2205.98080
# 1335   18  36.850         0     no   1629.83350
# 1336   21  25.800         0     no   2007.94500
# 1337   61  29.070         0    yes  29141.36030
#
# [1338 rows x 5 columns]

# %% [markdown]
# # 8. Squeeze parameters

# %%
pd.read_csv('insurance.csv', usecols=['charges']).squeeze('columns')
# Out:
# 0       16884.92400
# 1        1725.55230
# 2        4449.46200
# 3       21984.47061
# 4        3866.85520
#            ...
# 1333    10600.54830
# 1334     2205.98080
# 1335     1629.83350
# 1336     2007.94500
# 1337    29141.36030
# Name: charges, Length: 1338, dtype: float64

# %% [markdown]
# # 9. dtypes parameter

# %%
pd.read_csv('insurance.csv',dtype={'bmi':int}).info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File pandas/_libs/parsers.pyx:1116, in pandas._libs.parsers.TextReader._convert_tokens()
#
# TypeError: Cannot cast array data from dtype('float64') to dtype('int64') according to the rule 'safe'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 pd.read_csv('insurance.csv',dtype={'bmi':int}).info()
#
# ...
