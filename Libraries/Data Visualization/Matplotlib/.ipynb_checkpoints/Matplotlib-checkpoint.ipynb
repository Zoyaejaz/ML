# %% [markdown]
# Data is just a numbers until we turn it into a picture.

# %% [markdown]
# # ORIGIN OF THESE LIBRARIES

# %% [markdown]
# 1. MatplotLib: --> It was made by John Hunter in 2003.It's goal is to make plots like matlab(it's a high-level programming language and a numerical environment used by engineers for data-analytics,visualization and algorithmic developement)  in python.It is powerful but complex for the beginner.That's why seaborn comes
# 2. Seaborn: --> It was made by Michael waskom a neuroscientist. Think like seaborn is a stylish and a better upgrade of a matplotlib.
# 3. Cufflinks: --> It was made by Santiago palladino. And this was also an upgrade of Seaborn.

# %% [markdown]
# We can do Data visualization either by
# 1. With code: --> we can use Matplotlib, Seaborn and plotly to visualize data. It is very flexible. And it can easily integrate into apps,ML pipelines.
# 2. With Tools: --> We can use Power BI, Tableau, Google data Studio. It is limited to what the tool allow. It faces toughness on integrating it into apps and with ML pipelines.

# %% [markdown]
# # Matplotlib

# %%
#Importing Matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # Matplotlib Basics

# %%
x=np.linspace(0,5,11)     #it will generate the random 11 numbers from 0 to 5 with linear space in between all of them
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y=x**2
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y)    #plot make a line graph,in plot we have to pass axis, first one is x axis and 2nd one is y axis 
#vertical line is y axis and horizontal line is x axis

#Adding labels
plt.title("Square of a number")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
# Out:
# Text(0, 0.5, 'Y-axis')

# %% [markdown]
# # Subplots in Matplotlib

# %% [markdown]
# Subplots means we want to create mutiple plots at one time.

# %%
plt.subplot(2,2,1)   #subplot takes 3 arguments     #it will divide  the canvas into 2*2 box that's why we are seeing 4 boxes.And 1 means we are taking the 1st quadrant
plt.subplot(2,2,2)   #2 means we are taking the 2nd quadrant
plt.plot(x,y)       #it will plot the line for the just above code (in the 2nd quadrant)
plt.subplot(2,2,3)   #3 means we are taking the 3rd quadrant
plt.subplot(2,2,4)   #4 means we are taking the 4th quadrant
plt.plot(x**2,x**2)       #it will plot the line in the above code above plot(in the 4th quadrant)

# %% [markdown]
# # Objects Oriented way

# %%
fig=plt.figure()
fig.add_axes([0.1,0.1,0.8,0.8])
  #
# Out:
# <Axes: >

# %% [markdown]
# # Types of plots

# %% [markdown]
# ## 1. Scatter plot

# %%
plt.scatter(x,y)

# %% [markdown]
# ## 2.Histogram

# %%
from random import sample
data=sample(range(1,1000),100)
plt.hist(data)
# Out:
# (array([10.,  9.,  7., 15., 12.,  6.,  7., 10., 10., 14.]),
#  array([  3. , 102.2, 201.4, 300.6, 399.8, 499. , 598.2, 697.4, 796.6,
#         895.8, 995. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## 3. Box plot

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x13e5aa17110>,
#   <matplotlib.lines.Line2D at 0x13e5aa17250>],
#  'caps': [<matplotlib.lines.Line2D at 0x13e5aa17390>,
#   <matplotlib.lines.Line2D at 0x13e5aa174d0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x13e5aa16fd0>],
#  'medians': [<matplotlib.lines.Line2D at 0x13e5aa17610>],
#  'fliers': [<matplotlib.lines.Line2D at 0x13e5aa17750>],
#  'means': []}

# %% [markdown]
# # Saving plots

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.1,0.8,0.8])
ax=ax.plot(x,y)
plt.savefig("basicplot.png")

# %% [markdown]
# # Working with images

# %%
import matplotlib.image as mpimg

# %%
img=mpimg.imread("images.jpg")
img
# Out:
# array([[[235, 151,   3],
#         [235, 151,   3],
#         [236, 152,   4],
#         ...,
#         [246, 170,   7],
#         [246, 170,   7],
#         [246, 170,   7]],
#
#        [[235, 151,   3],
#         [235, 151,   3],
#         [236, 152,   4],
#         ...,
#         [246, 170,   7],
#         [246, 170,   7],
#         [246, 170,   7]],
#
#        [[235, 151,   3],
#         [235, 151,   3],
#         [236, 152,   4],
#         ...,
#         [246, 170,   7],
#         [246, 170,   7],
#         [246, 170,   7]],
#
#        ...,
#
#        [[251, 183,  12],
#         [251, 183,  12],
#         [251, 183,  12],
#         ...,
#         [253, 197,  16],
#         [253, 197,  16],
#         [253, 197,  16]],
#
#        [[250, 182,  11],
#         [250, 182,  11],
#         [250, 182,  11],
#         ...,
#         [253, 197,  16],
#         [253, 197,  16],
#         [253, 197,  16]],
#
#        [[249, 181,  10],
#         [249, 181,  10],
#         [250, 182,  11],
#         ...,
#         [253, 197,  16],
#         [253, 197,  16],
#         [253, 197,  16]]], shape=(360, 487, 3), dtype=uint8)

# %%
plt.imshow(img)

# %%
plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(486.5), np.float64(359.5), np.float64(-0.5))

# %%
cropped_img=img[50:200,100:300] # crop:rows 50-200, cols 100-300
plt.imshow(cropped_img)

# %% [markdown]
# # Optional Designing

# %%
plt.plot(x,y,color="green")

# %%
xaxis=np.linspace(0,5,11)

# %%
fig,ax=plt.subplots(figsize=(12,6))
ax.plot(xaxis,xaxis+1,color="red",linewidth=0.25)
ax.plot(xaxis,xaxis+2,color="red",linewidth=0.50)
ax.plot(xaxis,xaxis+3,color="red",linewidth=1.00)
ax.plot(xaxis,xaxis+4,color="red",linewidth=2.00)

# possible linestype options ‘-‘, ‘–’, ‘-.’, ‘:’, ‘steps’
ax.plot(xaxis,xaxis+5,color="green",lw=3,linestyle='-')
ax.plot(xaxis,xaxis+6,color="green",lw=3,ls='-.')
ax.plot(xaxis, xaxis+7, color="green",lw=3, ls=':')

# custom dash
line, = ax.plot(xaxis, xaxis+8, color="black", lw=1.50)
line.set_dashes([5, 50, 15, 50]) # format: line length, space length, ...

# possible marker symbols: marker = '+', 'o', '*', 's', ',', '.', '1', '2', '3', '4', ...
ax.plot(xaxis, xaxis+ 9, color="blue", lw=3, ls='-', marker='+')
ax.plot(xaxis, xaxis+10, color="blue", lw=3, ls='--', marker='o')
ax.plot(xaxis, xaxis+11, color="blue", lw=3, ls='-', marker='s')
ax.plot(xaxis, xaxis+12, color="blue", lw=3, ls='--', marker='1')
ax.plot(xaxis, xaxis+13, color="purple", lw=1, ls='-', marker='o', markersize=2)
ax.plot(xaxis, xaxis+14, color="purple", lw=1, ls='-', marker='o', markersize=4)
ax.plot(xaxis, xaxis+15, color="purple", lw=1, ls='-', marker='o', markersize=8, markerfacecolor="red")
ax.plot(xaxis, xaxis+16, color="purple", lw=1, ls='-', marker='s', markersize=8, 
        markerfacecolor="yellow", markeredgewidth=3, markeredgecolor="green");
