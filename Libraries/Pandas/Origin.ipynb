# %% [markdown]
# # PANDAS

# %% [markdown]
# Its name is inspired from panel data(It's an economic term for large multidimensional data).
#
# USE CASES:
# 1. Data Cleaning
# 2. Data Analysis
# 3. Data Transformation
# 4. Data Visualization
# 5. Data aggregation
# 6. Data Handling
# 7. Data Filtering and selection
# 8. Time series analysis

# %% [markdown]
# # SERIES

# %% [markdown]
# It is a one dimensional labelled array capable of holding any data type. The axis labels collectively called the index.

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,20,30]
arr=np.array([10,20,30])
d={'a':10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64
